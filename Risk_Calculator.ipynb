# %%
Location_number = {
    "Douala": 38,
    "Yaounde": 57,
    "Buea": 87,
    "Garoua": 40
}

User_location=input("Enter a locatiion: ")
if User_location in Location_number:
    Score = Location_number[User_location]
    if Score < 50:
        print("High Risk")
    else:
        print("Safe")
else:
    print("Location not found")
# Out:
# Enter a locatiion: Douala
# High Risk
